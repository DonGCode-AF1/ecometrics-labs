# %% [markdown]
# # 🧪 实验室模板：[在这里输入实验主题名称]
# ---
# *实证经济学交互式模拟实验室*
#
# ### 📖 实验室目标
# 1. **[目标 1]**：在此列出第一个核心直觉目标（例如：直观感受遗漏变量偏差对系数的影响）。
# 2. **[目标 2]**：在此列出第二个核心直觉目标。
# 3. **[目标 3]**：在此列出第三个核心直觉目标。

# %% [markdown]
# ## 1. 💡 理论直觉与物理机制
#
# 在这部分用**极简、精炼**的语言写出数理公式（使用 LaTeX 渲染）并阐述其背后的经济学直觉。
#
# > **注意：** 严格遵循 [ai-coding-skills.md](../ai-coding-skills.md) 指南：
# > - 杜绝使用任何“AI腔”表达（如“不是……而是……”）。
# > - 用逻辑和因果关系讲透为什么参数的变化会产生相应的效果。

# %% [markdown]
# ## 2. 🎛️ 交互式参数调优引擎 (Simulation Engine)
#
# 在此编写 Python 仿真代码，并使用 `ipywidgets` 绑定滑块。运行此单元格将渲染出交互滑块，用户可以拖动调整参数并实时出图。

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import ipywidgets as widgets
from scipy import stats

# 1. 定义核心模拟函数
def run_simulation(param1=1.0, param2=0.5):
    # [在此处编写您的模拟与仿真计算代码]
    
    # [在此处编写 Matplotlib 绘图代码]
    fig, ax = plt.subplots(figsize=(8, 5))
    ax.plot([0, 1], [param1, param2], label='示例折线')
    ax.set_title(f'参数 1: {param1}, 参数 2: {param2}')
    ax.legend()
    plt.show()

# 2. 使用 widgets 绑定滑块并调用 interact
widgets.interact(
    run_simulation,
    param1=widgets.FloatSlider(value=1.0, min=0.0, max=2.0, step=0.1, description='参数 1'),
    param2=widgets.FloatSlider(value=0.5, min=0.0, max=1.0, step=0.05, description='参数 2')
);

# %% [markdown]
# ## 3. 🎯 核心思想启发
#
# 在这里写出对实验结果的理论阐释和学术启发。记住，语言要精炼、准确、富有洞察力。
